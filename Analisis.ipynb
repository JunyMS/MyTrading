# %%
from modulos.indicadores import find_rsi_divergences_multi, detect_engulfing_patterns, find_rsi_divergences_single

# %%
tickers = ['TSLA','AAPL', 'MSFT', 'NVDA']
period = '90d'
# period = '1y'
# interval = '1h'
interval = '1d'

# %%
divs_por_ticker = find_rsi_divergences_multi(tickers, period=period, interval=interval)

for ticker, df_divs in divs_por_ticker.items():
    print(f"\n📈 Divergencias para {ticker}:")
    print(df_divs)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 📈 Divergencias para TSLA:
#        Fecha      Señal
# 0 2025-07-07  ++COMPRAR
# 1 2025-08-01  ++COMPRAR
# 2 2025-08-21  ++COMPRAR
#
# 📈 Divergencias para AAPL:
#        Fecha     Señal
# 0 2025-07-22  --VENDER
#
# 📈 Divergencias para MSFT:
#        Fecha     Señal
# 0 2025-08-04  --VENDER
#
# 📈 Divergencias para NVDA:
#        Fecha     Señal
# 0 2025-08-12  --VENDER

# %%
detect_engulfing_patterns(tickers, period=period, interval=interval)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# No se detectaron señales para TSLA.
#
# No se detectaron señales para AAPL.
#
# 📈 Señales para MSFT:
#                  Date  Compra Engulfing  Venta Engulfing
# time
# 2025-08-12 2025-08-12               1.0              NaN
#
# No se detectaron señales para NVDA.

# %%
find_rsi_divergences_single(ticker = 'AAPL', period=period, interval=interval)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                        Fecha      Señal
# 0  2025-05-30 15:30:00+00:00  ++COMPRAR
# 1  2025-06-05 19:30:00+00:00  ++COMPRAR
# 2  2025-06-09 16:30:00+00:00  ++COMPRAR
# 3  2025-06-13 13:30:00+00:00  ++COMPRAR
# 4  2025-06-17 17:30:00+00:00  ++COMPRAR
# 5  2025-06-26 14:30:00+00:00  ++COMPRAR
# 6  2025-06-30 14:30:00+00:00  ++COMPRAR
# 7  2025-07-07 17:30:00+00:00  ++COMPRAR
# 8  2025-07-09 15:30:00+00:00  ++COMPRAR
# 9  2025-07-10 14:30:00+00:00   --VENDER
# 10 2025-07-14 13:30:00+00:00  ++COMPRAR
# 11 2025-07-16 13:30:00+00:00   --VENDER
# 12 2025-07-21 13:30:00+00:00   --VENDER
# 13 2025-07-24 14:30:00+00:00   --VENDER
# 14 2025-08-13 18:30:00+00:00   --VENDER
# 15 2025-08-15 16:30:00+00:00  ++COMPRAR
# 16 2025-08-19 13:30:00+00:00   --VENDER
# 17 2025-08-25 13:30:00+00:00   --VENDER
# 18 2025-08-26 13:30:00+00:00  ++COMPRAR
# 19 2025-08-28 16:30:00+00:00   --VENDER
# 20 2025-09-02 14:30:00+00:00  ++COMPRAR
# ...
